# %%
import fastf1
import pandas as pd

fastf1.Cache.enable_cache('cache')  # saves re-downloading

session = fastf1.get_session(2023, 'Bahrain', 'Q')
session.load()

laps = session.laps
print(laps.columns.tolist())
print(laps.head())
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Qualifying [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '55', '14', '63', '44', '18', '31', '27', '4', '77', '24', '22', '23', '2', '20', '81', '21', '10']
# ...

# %%
laps[['Driver', 'Compound', 'TyreLife', 'LapTime', 'IsPersonalBest', 'Deleted', 'IsAccurate']].dropna()
# Out:
#     Driver Compound  TyreLife                LapTime  IsPersonalBest  Deleted  \
# 2      VER     SOFT       3.0 0 days 00:01:31.295000            True    False
# 3      VER     SOFT       4.0 0 days 00:01:49.812000           False    False
# 5      VER     SOFT       2.0 0 days 00:02:12.516000           False    False
# 7      VER     SOFT       2.0 0 days 00:01:30.503000            True    False
# 8      VER     SOFT       3.0 0 days 00:02:05.756000           False    False
# ..     ...      ...       ...                    ...             ...      ...
# 247    DEV     SOFT       3.0 0 days 00:02:00.610000           False    False
# 249    GAS     SOFT       2.0 0 days 00:01:32.181000            True    False
# 250    GAS     SOFT       3.0 0 days 00:01:52.506000           False    False
# 252    GAS     SOFT       2.0 0 days 00:01:31.818000           False     True
# 253    GAS     SOFT       3.0 0 days 00:01:54.566000           False    False
#
#      IsAccurate
# ...

# %%
laps.info()
# Out:
# <class 'fastf1.core.Laps'>
# RangeIndex: 254 entries, 0 to 253
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                254 non-null    timedelta64[ns]
#  1   Driver              254 non-null    object
#  2   DriverNumber        254 non-null    object
#  3   LapTime             157 non-null    timedelta64[ns]
#  4   LapNumber           254 non-null    float64
#  5   Stint               254 non-null    float64
#  6   PitOutTime          89 non-null     timedelta64[ns]
#  7   PitInTime           89 non-null     timedelta64[ns]
#  8   Sector1Time         163 non-null    timedelta64[ns]
#  9   Sector2Time         246 non-null    timedelta64[ns]
#  10  Sector3Time         242 non-null    timedelta64[ns]
#  11  Sector1SessionTime  163 non-null    timedelta64[ns]
#  12  Sector2SessionTime  246 non-null    timedelta64[ns]
#  13  Sector3SessionTime  242 non-null    timedelta64[ns]
# ...

# %%
laps['LapTime'].describe()
# Out:
# count                          157
# mean     0 days 00:01:45.316707006
# std      0 days 00:00:14.798273104
# min         0 days 00:01:29.708000
# 25%         0 days 00:01:31.473000
# 50%         0 days 00:01:32.849000
# 75%         0 days 00:02:00.221000
# max         0 days 00:02:14.757000
# Name: LapTime, dtype: object

# %%
laps['Compound'].value_counts()
# Out:
# Compound
# SOFT      248
# MEDIUM      6
# Name: count, dtype: int64

# %%
clean = laps[laps['IsAccurate'] == True]
print(f"Total laps: {len(laps)}, Accurate laps: {len(clean)}")
# Out:
# Total laps: 254, Accurate laps: 80

# %%
# filter to only accurate laps first
df_clean = df[df['IsAccurate'] == True].copy()
print(f"Laps before: {len(df)}, Laps after: {len(df_clean)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # filter to only accurate laps first
# ----> 2 df_clean = df[df['IsAccurate'] == True].copy()
#       3 print(f"Laps before: {len(df)}, Laps after: {len(df_clean)}")
#
# NameError: name 'df' is not defined
